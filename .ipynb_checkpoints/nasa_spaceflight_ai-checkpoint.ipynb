# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(
    "GLDS-168_rna_seq_Mmus_C57-6J_LVR_RR1_BSL_noERCC_Rep5_M10.isoforms.results",
    sep="\t"
)

print(df.shape)

df.head()
# Out:
# (141954, 8)
#         transcript_id             gene_id  length  effective_length  \
# 0  ENSMUST00000000001  ENSMUSG00000000001    3262           3077.91
# 1  ENSMUST00000000003  ENSMUSG00000000003     902            717.91
# 2  ENSMUST00000114041  ENSMUSG00000000003     697            512.91
# 3  ENSMUST00000000028  ENSMUSG00000000028    2143           1958.91
# 4  ENSMUST00000096990  ENSMUSG00000000028    1747           1562.91
#
#    expected_count    TPM   FPKM  IsoPct
# 0          8486.0  14.65  33.38  100.00
# 1             0.0   0.00   0.00    0.00
# 2             0.0   0.00   0.00    0.00
# 3            63.0   0.17   0.39   97.66
# 4             0.0   0.00   0.00    0.00

# %%
top_genes = df.sort_values("TPM", ascending=False)

top_genes.head(20)
# Out:
#              transcript_id             gene_id  length  effective_length  \
# 120116  ENSMUST00000174924  ENSMUSG00000099021     300            119.35
# 120345  ENSMUST00000175032  ENSMUSG00000099250     300            119.35
# 91001   ENSMUST00000083103  ENSMUSG00000065037     331            148.88
# 113088  ENSMUST00000175096  ENSMUSG00000092837     319            137.36
# 41763   ENSMUST00000031314  ENSMUSG00000029368    2034           1849.91
# 116720  ENSMUST00000179621  ENSMUSG00000096349     164             15.94
# 109029  ENSMUST00000157463  ENSMUSG00000088088     271             92.66
# 113789  ENSMUST00000178333  ENSMUSG00000093815     164             15.94
# 116592  ENSMUST00000101833  ENSMUSG00000096243     141              7.62
# 114410  ENSMUST00000177864  ENSMUSG00000094377     141              7.62
# 90955   ENSMUST00000083011  ENSMUSG00000064945     102              1.14
# 122800  ENSMUST00000190277  ENSMUSG00000101111     783            598.91
# ...

# %%
top10 = top_genes.head(10)

plt.figure(figsize=(12,6))

plt.bar(top10["gene_id"], top10["TPM"])

plt.xticks(rotation=90)

plt.title("Top 10 expressed genes in NASA spaceflight sample")

plt.ylabel("TPM")

plt.xlabel("Gene ID")

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.bar(top10["gene_id"], top10["TPM"])

plt.xticks(rotation=90)

plt.title("Top 10 expressed genes in NASA spaceflight sample")

plt.ylabel("TPM")

plt.xlabel("Gene ID")

plt.tight_layout()

plt.savefig("figures/top10_spaceflight_genes.png")

plt.show()

# %%
import os
os.makedirs("figures", exist_ok=True)

# %%
heatmap_data = top_genes.head(20)[["TPM"]]

plt.figure(figsize=(6,10))

sns.heatmap(
    heatmap_data,
    cmap="viridis",
    annot=False
)

plt.title("Top expressed genes heatmap")

plt.show()

# %%
plt.figure(figsize=(6,10))

sns.heatmap(
    heatmap_data,
    cmap="viridis",
    annot=False
)

plt.title("Top expressed genes heatmap")
plt.tight_layout()

plt.savefig("figures/top_genes_heatmap.png", dpi=300)

plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
expression_data = df[["TPM", "FPKM", "expected_count"]]

expression_scaled = StandardScaler().fit_transform(expression_data)

# %%
pca = PCA(n_components=2)

principal_components = pca.fit_transform(expression_scaled)

pca_df = pd.DataFrame(
    data=principal_components,
    columns=["PC1", "PC2"]
)

pca_df.head()
# Out:
#         PC1       PC2
# 0  0.151433  0.211506
# 1 -0.018252 -0.010883
# 2 -0.018252 -0.010883
# 3 -0.016925 -0.009276
# 4 -0.018252 -0.010883

# %%
plt.figure(figsize=(10,8))

plt.scatter(
    pca_df["PC1"],
    pca_df["PC2"],
    alpha=0.5
)

plt.title("PCA of NASA RNA-seq expression data")

plt.xlabel("Principal Component 1")

plt.ylabel("Principal Component 2")

plt.show()

# %%
import pandas as pd

df = pd.read_csv(
    "GLDS-168_rna_seq_Mmus_C57-6J_LVR_RR1_BSL_noERCC_Rep5_M10.isoforms.results",
    sep="\t"
)

df.head()
# Out:
#         transcript_id             gene_id  length  effective_length  \
# 0  ENSMUST00000000001  ENSMUSG00000000001    3262           3077.91
# 1  ENSMUST00000000003  ENSMUSG00000000003     902            717.91
# 2  ENSMUST00000114041  ENSMUSG00000000003     697            512.91
# 3  ENSMUST00000000028  ENSMUSG00000000028    2143           1958.91
# 4  ENSMUST00000096990  ENSMUSG00000000028    1747           1562.91
#
#    expected_count    TPM   FPKM  IsoPct
# 0          8486.0  14.65  33.38  100.00
# 1             0.0   0.00   0.00    0.00
# 2             0.0   0.00   0.00    0.00
# 3            63.0   0.17   0.39   97.66
# 4             0.0   0.00   0.00    0.00

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# wybór cech
X = df[['TPM', 'FPKM', 'expected_count']]

# skalowanie danych
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# podgląd
df[['gene_id', 'TPM', 'cluster']].head()
# Out:
#               gene_id    TPM  cluster
# 0  ENSMUSG00000000001  14.65        0
# 1  ENSMUSG00000000003   0.00        0
# 2  ENSMUSG00000000003   0.00        0
# 3  ENSMUSG00000000028   0.17        0
# 4  ENSMUSG00000000028   0.00        0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))

plt.scatter(
    df['TPM'],
    df['FPKM'],
    c=df['cluster'],
    alpha=0.6
)

plt.xlabel("TPM")
plt.ylabel("FPKM")
plt.title("Gene expression clusters")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))

plt.scatter(
    np.log1p(df['TPM']),
    np.log1p(df['FPKM']),
    c=df['cluster'],
    alpha=0.6
)

plt.xlabel("log1p(TPM)")
plt.ylabel("log1p(FPKM)")
plt.title("Gene expression clusters")

plt.show()

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 0    141951
# 1         2
# 2         1
# Name: count, dtype: int64

# %%
df.groupby('cluster')[['TPM', 'FPKM']].mean()
# Out:
#                    TPM           FPKM
# cluster
# 0             2.994321       6.821504
# 1        278988.975000  635573.880000
# 2         16972.290000   38665.120000

# %%
df.sort_values(by='TPM', ascending=False)[
    ['gene_id', 'TPM', 'FPKM', 'cluster']
].head(20)
# Out:
#                    gene_id        TPM       FPKM  cluster
# 120116  ENSMUSG00000099021  323010.47  735860.69        1
# 120345  ENSMUSG00000099250  234967.48  535287.07        1
# 91001   ENSMUSG00000065037   61070.88  139127.57        0
# 113088  ENSMUSG00000092837   21594.59   49195.33        0
# 41763   ENSMUSG00000029368   16972.29   38665.12        2
# 116720  ENSMUSG00000096349   11951.85   27227.91        0
# 109029  ENSMUSG00000088088    8225.24   18738.19        0
# 113789  ENSMUSG00000093815    7480.51   17041.60        0
# 116592  ENSMUSG00000096243    7078.61   16126.02        0
# 114410  ENSMUSG00000094377    6925.70   15777.66        0
# 90955   ENSMUSG00000064945    6613.37   15066.13        0
# 122800  ENSMUSG00000101111    6235.40   14205.07        0
# 138693  ENSMUSG00000115420    5495.65   12519.83        0
# 90598   ENSMUSG00000064351    5478.11   12479.85        0
# 105107  ENSMUSG00000084708    5083.56   11581.03        0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,8))

scatter = plt.scatter(
    np.log1p(df['TPM']),
    np.log1p(df['FPKM']),
    c=df['cluster'],
    alpha=0.7,
    s=10
)

plt.xlabel("log1p(TPM)")
plt.ylabel("log1p(FPKM)")
plt.title("RNA-seq Gene Clusters")

plt.colorbar(label="Cluster")

plt.grid(True)
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(10,7))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=df['cluster'],
    alpha=0.7,
    s=10
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA of RNA-seq clusters")

plt.colorbar(label="Cluster")

plt.show()

# %%
import numpy as np

X = np.log1p(df[['TPM', 'FPKM', 'expected_count']])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
df_filtered = df[df['TPM'] > 1].copy()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np

# wybór cech po filtracji
X = np.log1p(
    df_filtered[['TPM', 'FPKM', 'expected_count']]
)

# skalowanie
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# clustering
kmeans = KMeans(
    n_clusters=5,
    random_state=42,
    n_init=10
)

df_filtered['cluster'] = kmeans.fit_predict(X_scaled)

# podgląd
df_filtered[['gene_id', 'TPM', 'cluster']].head()
# Out:
#                gene_id     TPM  cluster
# 0   ENSMUSG00000000001   14.65        3
# 21  ENSMUSG00000000049  527.93        2
# 25  ENSMUSG00000000056    3.04        1
# 31  ENSMUSG00000000078    1.22        4
# 48  ENSMUSG00000000088   84.24        3

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(10,7))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=df_filtered['cluster'],
    alpha=0.7,
    s=15
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Filtered RNA-seq PCA")

plt.colorbar(label="Cluster")

plt.grid(True)

plt.show()

# %%
df_filtered['cluster'].value_counts()
# Out:
# cluster
# 4    4731
# 1    2952
# 0    2188
# 3    1385
# 2     506
# Name: count, dtype: int64

# %%
df_filtered.groupby('cluster')[
    ['TPM', 'FPKM']
].mean()
# Out:
#                  TPM         FPKM
# cluster
# 0           2.265402     5.160818
# 1           6.699136    15.261392
# 2        1803.666383  4108.991344
# 3          31.686318    72.185625
# 4           2.060454     4.693967

# %%
for c in sorted(df_filtered['cluster'].unique()):

    print(f"\n===== CLUSTER {c} =====")

    display(
        df_filtered[df_filtered['cluster'] == c]
        .sort_values(by='TPM', ascending=False)
        [['gene_id', 'TPM', 'FPKM']]
        .head(10)
    )
# Out:
# ===== CLUSTER 0 =====
#                    gene_id    TPM   FPKM
# 91027   ENSMUSG00000065089  34.65  78.95
# 90957   ENSMUSG00000064949  33.91  77.25
# 109083  ENSMUSG00000088158  32.23  73.42
# 91161   ENSMUSG00000065336  32.04  72.99
# 101419  ENSMUSG00000080478  27.67  63.03
# 114440  ENSMUSG00000094405  26.41  60.16
# 90793   ENSMUSG00000064666  25.11  57.19
# 91033   ENSMUSG00000065097  24.27  55.30
# 128509  ENSMUSG00000106355  24.14  55.00
# 113811  ENSMUSG00000093834  22.83  52.00
# ===== CLUSTER 1 =====
#                    gene_id    TPM   FPKM
# 90953   ENSMUSG00000064941  26.82  61.11
# 7160    ENSMUSG00000008683  20.05  45.67
# 91557   ENSMUSG00000065911  18.38  41.88
# 59071   ENSMUSG00000036570  18.25  41.59
# 71989   ENSMUSG00000043681  17.50  39.88
# 5253    ENSMUSG00000005547  17.40  39.65
# 113066  ENSMUSG00000092805  17.25  39.29
# 56573   ENSMUSG00000035048  17.15  39.08
# 60179   ENSMUSG00000037152  16.81  38.29
# 16335   ENSMUSG00000021040  16.80  38.28
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sample = df_filtered.sample(1000)

plt.figure(figsize=(8,10))

sns.heatmap(
    np.log1p(
        sample[['TPM','FPKM','expected_count']]
    ),
    cmap='viridis'
)

plt.title("RNA-seq Heatmap")
plt.show()
