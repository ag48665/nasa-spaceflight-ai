# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("GLDS-245_rna_seq_Normalized_Counts_GLbulkRNAseq.csv")

df.shape
# Out:
# (26335, 60)

# %%
gene_col = df.columns[0]

# wybieramy tylko 20 genów i 10 próbek
small = df.iloc[:20, :11]

small
# Out:
#             Unnamed: 0  Mmus_C57-6T_LVR_BSL_LAR_Rep1_B2  \
# 0   ENSMUSG00000000001                      5985.525443
# 1   ENSMUSG00000000028                        55.775198
# 2   ENSMUSG00000000031                        19.512916
# 3   ENSMUSG00000000037                         6.768447
# 4   ENSMUSG00000000049                     96466.082690
# 5   ENSMUSG00000000056                      2911.069662
# 6   ENSMUSG00000000058                       690.015205
# 7   ENSMUSG00000000078                      1158.145275
# 8   ENSMUSG00000000085                       190.042745
# 9   ENSMUSG00000000088                      5979.351968
# 10  ENSMUSG00000000093                       124.806006
# 11  ENSMUSG00000000094                         2.381909
# 12  ENSMUSG00000000120                       168.379879
# 13  ENSMUSG00000000126                         5.887692
# 14  ENSMUSG00000000127                       667.538933
# 15  ENSMUSG00000000131                      1052.608045
# 16  ENSMUSG00000000134                       448.674874
# 17  ENSMUSG00000000142                       176.187030
# 18  ENSMUSG00000000148                       231.861352
# 19  ENSMUSG00000000149                      2963.015169
#
#     Mmus_C57-6T_LVR_BSL_LAR_Rep2_B4  Mmus_C57-6T_LVR_BSL_LAR_Rep3_B5  \
# 0                       4331.106384                      3436.544733
# 1                         90.497068                        45.022624
# 2                         30.577524                         7.838029
# 3                          7.995053                         3.953946
# 4                      97953.065770                     55524.633478
# 5                       2741.741755                      1333.477357
# 6                        537.042538                      1419.052184
# 7                        870.915670                      1547.584123
# 8                        174.050664                       302.230019
# 9                       4427.475262                      4590.001245
# 10                       133.779567                       170.378858
# 11                         5.921006                         0.000000
# 12                       211.557847                       269.118436
# 13                        12.543762                        29.041816
# 14                       645.537632                       796.263333
# 15                      1303.166719                      1023.598669
# 16                       556.091801                       502.616464
# 17                       260.366888                       115.047945
# 18                       293.599722                       196.811609
# 19                      3444.330910                      2045.949977
#
#     Mmus_C57-6T_LVR_BSL_LAR_Rep4_B10  Mmus_C57-6T_LVR_BSL_LAR_Rep5_B6  \
# 0                        4696.007141                      5125.374549
# 1                          69.044200                        52.927148
# 2                          22.309049                        36.535472
# 3                           4.555665                         2.352663
# 4                       82009.365922                     74452.813446
# 5                        1451.213080                      2037.819692
# 6                         763.809242                       429.096821
# 7                        1100.835233                       775.941695
# 8                         166.118739                       209.856261
# 9                        4267.350220                      4243.807106
# 10                        111.104403                       124.478056
# 11                          2.707537                         0.874512
# 12                        165.990154                       271.456734
# 13                         20.080060                        16.426629
# 14                        628.056513                       627.440721
# 15                       1177.775858                      1405.604039
# 16                        628.695497                       704.969155
# 17                        134.286482                       257.465166
# 18                        163.366304                       352.331179
# 19                       1786.633134                      4184.996716
#
#     Mmus_C57-6T_LVR_BSL_LAR_Rep6_B7  Mmus_C57-6T_LVR_BSL_LAR_Rep7_B8  \
# 0                       4836.704361                      5734.187761
# 1                         45.269269                        51.385357
# 2                         69.830019                        32.153632
# 3                          4.048239                         5.658655
# 4                      81924.310027                     95586.126443
# 5                       2105.901016                      1540.274731
# 6                        512.244448                       601.178535
# 7                       1070.827771                       933.158176
# 8                        237.112215                       204.122802
# 9                       4373.371658                      5171.795849
# 10                       138.779884                       104.416079
# 11                         5.012662                         6.723571
# 12                       152.661194                       169.937582
# 13                        10.904325                        15.191602
# 14                       592.987253                       653.739388
# 15                      1448.298265                      1116.151374
# 16                       559.610993                       660.827852
# 17                       308.135633                       268.820225
# 18                       291.059161                       292.943743
# 19                      3540.081107                      2800.971638
#
#     Mmus_C57-6T_LVR_BSL_LAR_Rep8_B9  Mmus_C57-6T_LVR_BSL_LAR_Rep9_B1  \
# 0                       4814.578807                      4198.797953
# 1                         58.814422                        39.955600
# 2                         31.116212                        28.103922
# 3                          3.427602                         3.688935
# 4                      98908.296962                     84442.059741
# 5                       1508.616338                      3067.488996
# 6                        562.130133                       406.646188
# 7                       1019.721279                       853.001624
# 8                        273.616506                       184.246230
# 9                       4461.441945                      3226.903300
# 10                       125.897666                       137.060317
# 11                         0.000000                         4.056676
# 12                       181.297071                       262.958590
# 13                        23.165834                        17.638513
# 14                       583.432774                       559.226872
# 15                      1159.523485                      1295.530825
# 16                       543.644489                       607.610548
# 17                       152.661661                       289.043529
# 18                       239.024401                       302.545127
# 19                      2860.774007                      3529.163055
#
#     Mmus_C57-6T_LVR_BSL_LAR_Rep10_B3
# 0                        4973.015027
# 1                          55.563577
# 2                          37.614001
# 3                           4.150417
# 4                       81578.339689
# 5                        2467.990911
# 6                         674.934978
# 7                         974.544732
# 8                         173.310150
# 9                        3967.605096
# 10                        134.472116
# 11                          0.000000
# 12                        247.495959
# 13                          8.754668
# 14                        635.843927
# 15                       1100.285810
# 16                        411.796576
# 17                        198.349528
# 18                        238.901501
# 19                       2275.304979

# %%
plt.figure(figsize=(12,6))

plt.plot(small.iloc[:,1:].T)

plt.title("NASA OSD-245 RNA-seq expression profiles")
plt.xlabel("Samples")
plt.ylabel("Normalized expression")

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
